# %%
h_bd = 0
l_bd = 0
sc_l_bd = 0
sc_h_bd = 0
num = 0
n = input()
k0 = n/10**6
k6 = n % 10
k1 = (n-k1*10**6)/10**5
k2 = (n-k1*10**6-k2*10**5)/10**4
k3 = (n-k1*10**6-k2*10**5-k3*10**4)/10**3
k4 = (n-k1*10**6-k2*10**5-k3*10**4-k4*10**3)/10**2
k5 = (n-k1*10**6-k2*10**5-k3*10**4-k4*10**3-k5*10**2)/10**1
p=0
if k1!=0:
    p=7
    num = 168570
elif k2!=0:
    p=6
    h_bd = 999999
    l_bd = 100000
    sc_l_bd = 32490
    sc_h_bd = 168570
elif k3!=0:
    p=5
    h_bd = 99999
    l_bd = 10000
    sc_l_bd = 5274
    sc_h_bd = 32490
elif k4!=0:
    p=4
    h_bd = 9999
    l_bd = 1000
    sc_l_bd = 738
    sc_h_bd = 5274
elif k5!=0:
    p=3
    h_bd = 999
    l_bd = 100
    sc_l_bd = 90
    sc_h_bd = 738
elif k6!=0:
    p=2
    h_bd = 99
    l_bd = 10
    sc_l_bd = 9
    sc_h_bd = 90
else:
    p=1
    num = n
sc_diap = 0
d1 = n - l_bd
d2 = h_bd - n
if d1 > d2:
    for i in range(n+1,h_bd+1):
        k1 = i/10**6
        k7 = i % 10
        k2 = (i-k1*10**6)/10**5
        k3 = (i-k1*10**6-k2*10**5)/10**4
        k4 = (i-k1*10**6-k2*10**5-k3*10**4)/10**3
        k5 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3)/10**2
        k6 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3-k5*10**2)/10**1
      
        if  k1!= 0:
            if len(list(set([k1])|set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==7:
                sc_diap += 1
        elif k2!= 0:
            if len(list(set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==6:
                sc_diap += 1
        elif k3!= 0:
            if len(list(set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==5:
                sc_diap += 1
        elif k4!= 0:
            if len(list(set([k4])|set([k5])|set([k6])|set([k7])))==4:
                sc_diap += 1
        elif k5!= 0:
            if len(list(set([k5])|set([k6])|set([k7])))==3:
                sc_diap += 1
        elif k6!= 0:
            if len(list(set([k6])|set([k7])))==2:
                sc_diap += 1
    num = num + sc_h_bd - sc_diap
    print num
else:
    for i in range(l_bd,n+1):
        k1 = i/10**6
        k7 = i % 10
        k2 = (i-k1*10**6)/10**5
        k3 = (i-k1*10**6-k2*10**5)/10**4
        k4 = (i-k1*10**6-k2*10**5-k3*10**4)/10**3
        k5 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3)/10**2
        k6 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3-k5*10**2)/10**1
      
        if  k1!= 0:
            if len(list(set([k1])|set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==7:
                sc_diap += 1
        elif k2!= 0:
            if len(list(set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==6:
                sc_diap += 1
        elif k3!= 0:
            if len(list(set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==5:
                sc_diap += 1
        elif k4!= 0:
            if len(list(set([k4])|set([k5])|set([k6])|set([k7])))==4:
                sc_diap += 1
        elif k5!= 0:
            if len(list(set([k5])|set([k6])|set([k7])))==3:
                sc_diap += 1
        elif k6!= 0:
            if len(list(set([k6])|set([k7])))==2:
                sc_diap += 1
    num = num + sc_l_bd + sc_diap
    print num

# %%
n = input()
sc = 10
for i in range(12,n+1):
    k1 = i/10**6
    k7 = i % 10
    k2 = (i-k1*10**6)/10**5
    k3 = (i-k1*10**6-k2*10**5)/10**4
    k4 = (i-k1*10**6-k2*10**5-k3*10**4)/10**3
    k5 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3)/10**2
    k6 = (i-k1*10**6-k2*10**5-k3*10**4-k4*10**3-k5*10**2)/10**1
    if i == 999000:
        print k1,k2,k3,k4,k5,k6,k7
    if  k1!= 0:
        if len(list(set([k1])|set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==7:
            sc += 1
    elif k2!= 0:
        if len(list(set([k2])|set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==6:
            sc += 1
    elif k3!= 0:
        if len(list(set([k3])|set([k4])|set([k5])|set([k6])|set([k7])))==5:
            sc += 1
    elif k4!= 0:
        if len(list(set([k4])|set([k5])|set([k6])|set([k7])))==4:
            sc += 1
    elif k5!= 0:
        if len(list(set([k5])|set([k6])|set([k7])))==3:
            sc += 1
    elif k6!= 0:
        if len(list(set([k6])|set([k7])))==2:
            sc += 1
print sc
# Out:
# 3215
# 1868

# %%
from math import factorial
h_bd = 0
l_bd = 0
sc_l_bd = 0
sc_h_bd = 0
s1=0
s2=0
s3=0
s4=0
s5=0
s6=0
num = 0
n = input()
k0 = n/10**6
k6 = n % 10
k1 = (n-k0*10**6)/10**5
k2 = (n-k0*10**6-k1*10**5)/10**4
k3 = (n-k0*10**6-k1*10**5-k2*10**4)/10**3
k4 = (n-k0*10**6-k1*10**5-k2*10**4-k3*10**3)/10**2
k5 = (n-k0*10**6-k1*10**5-k2*10**4-k3*10**3-k4*10**2)/10**1
p=0
if k0!=0:
    p=7
    num = 168570
elif k1!=0:
    p=6
    h_bd = 999999
    l_bd = 100000
    sc_l_bd = 32490
    sc_h_bd = 168570
elif k2!=0:
    p=5
    h_bd = 99999
    l_bd = 10000
    sc_l_bd = 5274
    sc_h_bd = 32490
elif k3!=0:
    p=4
    h_bd = 9999
    l_bd = 1000
    sc_l_bd = 738
    sc_h_bd = 5274
elif k4!=0:
    p=3
    h_bd = 999
    l_bd = 100
    sc_l_bd = 90
    sc_h_bd = 738
elif k5!=0:
    p=2
    h_bd = 99
    l_bd = 10
    sc_l_bd = 9
    sc_h_bd = 90
else:
    p=1
    num = n
sc_diap = 0
if p==2:
    if k5>k6:
        num = sc_l_bd + (k5-1)*factorial(9)/factorial(8) + k6 + 1
    else:
        num = sc_l_bd + (k5-1)*factorial(9)/factorial(8) + k6
elif p==3:
    if k4>k5:
        if k4>k6:
            num = sc_l_bd + (k4-1)*factorial(9)/factorial(7) + k5*factorial(8)/factorial(7)+ k6 + 1
        else:
            num = sc_l_bd + (k4-1)*factorial(9)/factorial(7) + k5*factorial(8)/factorial(7)+ k6
    elif k6<k4:
        num = sc_l_bd + (k4-1)*factorial(9)/factorial(7) + (k5-1)*factorial(8)/factorial(7)+ k6 + 1
    elif k6<k5:
        num = sc_l_bd + (k4-1)*factorial(9)/factorial(7) + (k5-1)*factorial(8)/factorial(7)+ k6
    else:
        num = sc_l_bd + (k4-1)*factorial(9)/factorial(7) + (k5-1)*factorial(8)/factorial(7)+ k6 - 1
elif p==4:
    x1=0
    s1=0
    x2=0
    s2=0
    
    x3 = k3-1
    s3 = x3*factorial(9)/factorial(6)
    
    m_w_k4 = range(0,-2,-1)
    m_n_k4 = sorted([k3,k4])
    mas_k4 = dict(zip(m_n_k4,m_w_k4))
    x4 = k4 + mas_k4[k4]
    s4 = x4*factorial(8)/factorial(6)
    
    m_w_k5 = range(0,-3,-1)
    m_n_k5 = sorted([k3,k4,k5])
    mas_k5 = dict(zip(m_n_k5,m_w_k5))
    x5 = k5 + mas_k5[k5]
    s5 = x5*factorial(7)/factorial(6)
        
    m_w_k6 = range(0,-4,-1)
    m_n_k6 = sorted([k3,k4,k5,k6])
    mas_k6 = dict(zip(m_n_k6,m_w_k6))
    x6 = k6 + mas_k6[k6] + 1
    s6 = x6
    
    num = sc_l_bd + s1 + s2 + s3 + s4 + s5 + s6
    print k1,k2,k3,k4,k5,k6
    print 'x=', x1,x2,x3,x4,x5,x6
    print sc_l_bd,s1,s2,s3,s4,s5,s6
elif p==5:
    x1=0
    s1=0
    x2 = k2-1
    s2 = x2*factorial(9)/factorial(5)
    
    m_w_k3 = range(0,-2,-1)
    m_n_k3 = sorted([k2,k3])
    mas_k3 = dict(zip(m_n_k3,m_w_k3))
    x3 = k3 + mas_k3[k3]
    s3 = x3*factorial(8)/factorial(5)
    
    m_w_k4 = range(0,-3,-1)
    m_n_k4 = sorted([k2,k3,k4])
    mas_k4 = dict(zip(m_n_k4,m_w_k4))
    x4 = k4 + mas_k4[k4]
    s4 = x4*factorial(7)/factorial(5)
    
    m_w_k5 = range(0,-4,-1)
    m_n_k5 = sorted([k2,k3,k4,k5])
    mas_k5 = dict(zip(m_n_k5,m_w_k5))
    x5 = k5 + mas_k5[k5]
    s5 = x5*factorial(6)/factorial(5)
    
    m_w_k6 = range(0,-5,-1)
    m_n_k6 = sorted([k2,k3,k4,k5,k6])
    mas_k6 = dict(zip(m_n_k6,m_w_k6))
    x6 = k6 + mas_k6[k6] + 1
    s6 = x6
    
    num = sc_l_bd + s1 + s2 + s3 + s4 + s5 + s6
    print k1,k2,k3,k4,k5,k6
    print 'x=', x1,x2,x3,x4,x5,x6
    print sc_l_bd,s1,s2,s3,s4,s5,s6
elif p==6:
    x1 = k1-1
    s1 = x1*factorial(9)/factorial(4)
    
    m_w_k2 = range(0,-2,-1)
    m_n_k2 = sorted([k1,k2])
    mas_k2 = dict(zip(m_n_k2,m_w_k2))
    x2 = k2 + mas_k2[k2]
    s2 = x2*factorial(8)/factorial(4)
    
    m_w_k3 = range(0,-3,-1)
    m_n_k3 = sorted([k1,k2,k3])
    mas_k3 = dict(zip(m_n_k3,m_w_k3))
    x3 = k3 + mas_k3[k3]
    s3 = x3*factorial(7)/factorial(4)
    
    m_w_k4 = range(0,-4,-1)
    m_n_k4 = sorted([k1,k2,k3,k4])
    mas_k4 = dict(zip(m_n_k4,m_w_k4))
    x4 = k4 + mas_k4[k4]
    s4 = x4*factorial(6)/factorial(4)
    
    m_w_k5 = range(0,-5,-1)
    m_n_k5 = sorted([k1,k2,k3,k4,k5])
    mas_k5 = dict(zip(m_n_k5,m_w_k5))
    x5 = k5 + mas_k5[k5]
    s5 = x5*factorial(5)/factorial(4)
    
    m_w_k6 = range(0,-6,-1)
    m_n_k6 = sorted([k1,k2,k3,k4,k5,k6])
    mas_k6 = dict(zip(m_n_k6,m_w_k6))
    x6 = k6 + mas_k6[k6] + 1
    s6 = x6
    
    num = sc_l_bd + s1 + s2 + s3 + s4 + s5 + s6
    print k1,k2,k3,k4,k5,k6
    print 'x=', x1,x2,x3,x4,x5,x6
    print sc_l_bd,s1,s2,s3,s4,s5,s6
print num
# Out:
# 3215
# 0 0 3 2 1 5
# x= 0 0 2 2 1 3
# 738 0 0 1008 112 7 3
# 1868

# %%
k1 =5 
k2 =2
k3 =2
k4 =1 
mas_k = ['k1','k2','k3','k4']
mas_n = [k1,k2,k3,k4]
mas = zip(mas_k,mas_n)
print mas
sorted(mas,key=lambda x: x[1])
mas_w = range(0,-4,-1)
mas2 = zip(mas,mas_w)
print mas2
dict_k = dict(mas2)
print dict_k[('k2',k2)]
# Out:
# [('k1', 5), ('k2', 2), ('k3', 2), ('k4', 1)]
# [(('k1', 5), 0), (('k2', 2), -1), (('k3', 2), -2), (('k4', 1), -3)]
# -1
